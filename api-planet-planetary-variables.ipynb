# %%
import requests
import time
import pandas as pd
from io import StringIO
import geopandas as gpd
from shapely.geometry import Polygon, MultiPolygon
from shapely.ops import unary_union

# %% [markdown]
# # Setup

# %%
SHAPEFILE_PATH = ""

# %%
PL_API_KEY = ""

# %% [markdown]
# # Verification
# It checks to see if your organization has access/subscription for the Planetary Variables

# %%
auth = requests.auth.HTTPBasicAuth(PL_API_KEY, "")
r = requests.get("https://api.planet.com/auth/v1/experimental/public/my/subscriptions", auth=auth)
print(r.status_code)
print(r.text[:400])
# Out:
# 200
# [{"active_from":"2025-02-18T00:00:00+00:00","active_to":"2026-02-17T23:59:59.999999+00:00","basemap_quad_quota":null,"basemap_tile_quota":{"current":0,"current_updated":null,"enabled":true,"limit":0,"metering":"tile","overage":false,"refresh":null,"reset":null,"updated_at":"2025-02-17T22:09:53.623532+00:00"},"created_at":"2025-02-17T22:09:53.592369+00:00","deleted_at":null,"id":781516,"organizatio

# %%
BASE_URL = "https://api.planet.com/subscriptions/v1"
r = requests.get(BASE_URL, auth=auth)
print(r.status_code)
print(r.text[:600])
# Out:
# 200
# {"_links":{"_self":"https://api.planet.com/subscriptions/v1"},"subscriptions":[{"name":"SWC time-series - minha AOI","source":{"type":"soil_water_content","parameters":{"id":"SWC-AMSR2-X_V2.0_100","geometry":{"type":"Polygon","coordinates":[[[-45.49446501255313,-14.753073442714642],[-45.49436462376634,-14.753074289911964],[-45.49426426555895,-14.75307683124583],[-45.49416396850103,-14.753081065942084],[-45.49406376314404,-14.75308699271069],[-45.49396368001151,-14.753094609746157],[-45.49386374958974,-14.75310391472808],[-45.493764002318485,-14.753114904821885],[-45.49366446858174,-14.75312757

# %% [markdown]
# ## Lists your access to products

# %%
url = "https://api.planet.com/account/v1/my/products"

r = requests.get(
    url,
    headers={"Authorization": f"api-key {PL_API_KEY}", "Content-Type": "application/json"},
)
r.raise_for_status()
products = r.json()
for p in products.get("results", []):
    print(p.get("id"), p.get("name"), p.get("title"), "supports_reservation=", p.get("supports_reservation"))
# Out:
# 726 LST_100M Land Surface Temperature 100m + 20m supports_reservation= True
# 728 SWC_100M Soil Water Content 100m + 20m supports_reservation= True
# 296983 PU_PLATFORM_ACCESS_SMALL_ENTERPRISE Platform Access, Small Enterprise supports_reservation= False
# 727 BMP_10M Crop Biomass 10m + 3m supports_reservation= True

# %% [markdown]
# ## Filters by type (in this case Soil Water)

# %%
results = products.get("results", [])

swc = [p for p in results if "SWC" in (p.get("name") or "") or "Soil Water" in (p.get("title") or "")]
for p in swc:
    print("ID:", p["id"])
    print("Name:", p["name"])
    print("Title:", p["title"])
    print("Resource IDs:", p.get("resource_ids", []))
    print("supports_reservation:", p.get("supports_reservation"))
    print("-"*60)
# Out:
# ID: 728
# Name: SWC_100M
# Title: Soil Water Content 100m + 20m
# Resource IDs: ['SWC-AMSR2-C_V2.0_100', 'SWC-AMSR2-X_V2.0_100', 'SWC-SMAP-L_V2.0_100', 'SWC-field_V1.0_20']
# supports_reservation: True
# ------------------------------------------------------------

# %% [markdown]
# # Code Execution
# ## Helper function to read a SHAPEFILE and transform to an AOI

# %%
def shapefile_to_clip_aoi(shp_path: str):
    gdf = gpd.read_file(shp_path)

    if gdf.empty:
        raise ValueError("Shapefile vazio.")

    # garante CRS em WGS84 (lon/lat)
    if gdf.crs is None:
        raise ValueError("Shapefile sem CRS definido. Defina gdf.set_crs(...) antes.")
    gdf = gdf.to_crs(epsg=4326)

    # junta tudo num único polígono (se tiver mais de 1 feição)
    geom = unary_union(gdf.geometry)

    # se vier MultiPolygon, pega o maior (ou adapte para usar todos)
    if isinstance(geom, MultiPolygon):
        geom = max(list(geom.geoms), key=lambda p: p.area)

    if not isinstance(geom, Polygon):
        raise TypeError(f"Geometria não é Polygon/MultiPolygon. Veio: {geom.geom_type}")

    # GeoJSON-like dict no mesmo formato do clip_aoi
    geo = gpd.GeoSeries([geom], crs="EPSG:4326").__geo_interface__["features"][0]["geometry"]
    # geo já sai como {"type":"Polygon","coordinates":[...]}
    return geo

clip_aoi = shapefile_to_clip_aoi(SHAPEFILE_PATH)
clip_aoi
# Out:
# {'type': 'Polygon',
#  'coordinates': (((-45.49446501255313, -14.753073442714642),
#    (-45.49436462376634, -14.753074289911964),
#    (-45.49426426555895, -14.75307683124583),
#    (-45.49416396850103, -14.753081065942084),
#    (-45.49406376314404, -14.75308699271069),
#    (-45.49396368001151, -14.753094609746157),
#    (-45.49386374958974, -14.75310391472808),
#    (-45.493764002318485, -14.753114904821885),
#    (-45.49366446858174, -14.753127576679582),
#    (-45.49356517869845, -14.753141926440932),
#    (-45.49346616291326, -14.753157949734534),
#    (-45.49336745138734, -14.753175641679151),
#    (-45.4932690741892, -14.753194996885249),
#    (-45.49317106128546, -14.753216009456592),
#    (-45.493073442531816, -14.753238672992085),
#    (-45.49297624766387, -14.753262980587662),
#    (-45.49287950628815, -14.753288924838456),
#    (-45.49278324787298, -14.753316497841016),
#    (-45.49268750173963, -14.753345691195717),
#    (-45.4925922970533, -14.753376496009315),
#    (-45.492497662814245, -14.753408902897698),
#    (-45.49240362784898, -14.753442901988713),
#    (-45.492310220801464, -14.753478482925129),
#    (-45.492217470124395, -14.7535156348679),
#    (-45.492125404070514, -14.753554346499387),
#    (-45.49203405068405, -14.753594606026804),
#    (-45.4919434377921, -14.753636401185858),
#    (-45.49185359299628, -14.753679719244467),
#    (-45.49176454366413, -14.753724547006623),
#    (-45.49167631692098, -14.75377087081641),
#    (-45.49158893964152, -14.753818676562224),
#    (-45.491502438441735, -14.75386794968097),
#    (-45.49141683967073, -14.753918675162605),
#    (-45.49133216940271, -14.753970837554649),
#    (-45.49124845342905, -14.754024420966886),
#    (-45.491165717250475, -14.754079409076265),
#    (-45.4910839860692, -14.754135785131806),
#    (-45.49100328478136, -14.754193531959743),
#    (-45.490923637969324, -14.754252631968756),
#    (-45.49084506989429, -14.754313067155302),
725,-14.756552172413059],[-45.48909492180221,-14.756642498580083],[-45.48905976356936,-14.756733431916127],[-45.48902625182772,-14.756824944721258],[-45.48899439678528,-14.756917009119071],[-45.48896420814539,-14.757009597065194],[-45.48893569510381,-14.75710268035578],[-45.488908866345895,-14.75719623063614],[-45.48888373004394,-14.75729021940937],[-45.48886029385471,-14.757384618045014],[-45.48883856491707,-14.757479397787856],[-45.488818549849896,-14.757574529766543],[-45.48880025474996,-14.757669985002538],[-45.48878368519012,-14.757765734418847],[-45.488768846217646,-14.75786174884887],[-45.48875574235261,-14.757957999045393],[-45.48874437758658,-14.758054455689338],[-45.48873475538139,-14.758151089398845],[-45.48872687866803,-14.758247870738137],[-45.48872074984584,-14.758344770226488],[-45.488716370781724,-14.758441758347242],[-45.48871374280958,-14.758538805556787],[-45.488712866729905,-14.758635882293534],[-45.48871374280958,-14.758732958986945],[-45.488716370781724,-14.758830006066558],[-45.48872074984584,-14. ...
# 'f3155727-4cd2-4bcf-a561-c1e5d8e2e373'

# %% [markdown]
# ## Process the subscription id request

# %%
import time

results_url = f"https://api.planet.com/subscriptions/v1/{subscription_id}/results"
results = None
while True:
    resp = requests.get(results_url, auth=auth)
    resp.raise_for_status()
    data = resp.json()

    if data.get("results") and len(data["results"]) > 0:
        print("✅ Resultados prontos!")
        results = (data["results"])
        break

    print("⏳ Ainda processando... aguardando 60s")
    time.sleep(60)
# Out:
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s
# ⏳ Ainda processando... aguardando 60s

# %% [markdown]
# ## Parses the result

# %%
import pandas as pd

if(len(results))
    rows = []
    for r in results:
        props = r.get("properties", {})
        stats = props.get("statistics", [])
    
        # transforma lista de stats em dict: {"mean": 0.274, "valid_percent": 100}
        stat_map = {s["name"]: s.get("value") for s in stats}
    
        rows.append({
            "datetime_utc": r.get("item_datetime"),
            "local_solar_time": props.get("local_solar_time"),
            "source_id": props.get("source_id"),
            "mean_swc": stat_map.get("mean"),
            "valid_percent": stat_map.get("valid_percent"),
            "result_id": r.get("id"),
            "status": r.get("status")
        })
    
    df = pd.DataFrame(rows)
    
    # tipos e ordenação
    df["datetime_utc"] = pd.to_datetime(df["datetime_utc"], utc=True)
    df = df.sort_values("datetime_utc").reset_index(drop=True)
    
    df
# Out:
#                 datetime_utc  local_solar_time             source_id  \
# 0  2024-03-21 04:30:00+00:00  2024-03-21T01:30  SWC-AMSR2-X_V2.0_100
# 1  2024-03-22 04:30:00+00:00  2024-03-22T01:30  SWC-AMSR2-X_V2.0_100
# 2  2024-03-23 04:30:00+00:00  2024-03-23T01:30  SWC-AMSR2-X_V2.0_100
# 3  2024-03-25 04:30:00+00:00  2024-03-25T01:30  SWC-AMSR2-X_V2.0_100
# 4  2024-03-27 04:30:00+00:00  2024-03-27T01:30  SWC-AMSR2-X_V2.0_100
# 5  2024-03-28 04:30:00+00:00  2024-03-28T01:30  SWC-AMSR2-X_V2.0_100
# 6  2024-03-29 04:30:00+00:00  2024-03-29T01:30  SWC-AMSR2-X_V2.0_100
# 7  2024-03-30 04:30:00+00:00  2024-03-30T01:30  SWC-AMSR2-X_V2.0_100
# 8  2024-03-31 04:30:00+00:00  2024-03-31T01:30  SWC-AMSR2-X_V2.0_100
# 9  2024-04-01 04:30:00+00:00  2024-04-01T01:30  SWC-AMSR2-X_V2.0_100
# 10 2024-04-02 04:30:00+00:00  2024-04-02T01:30  SWC-AMSR2-X_V2.0_100
# 11 2024-04-03 04:30:00+00:00  2024-04-03T01:30  SWC-AMSR2-X_V2.0_100
# 12 2024-04-04 04:30:00+00:00  2024-04-04T01:30  SWC-AMSR2-X_V2.0_100
# 13 2024-04-05 04:30:00+00:00  2024-04-05T01:30  SWC-AMSR2-X_V2.0_100
# 14 2024-04-06 04:30:00+00:00  2024-04-06T01:30  SWC-AMSR2-X_V2.0_100
# 15 2024-04-07 04:30:00+00:00  2024-04-07T01:30  SWC-AMSR2-X_V2.0_100
# 16 2024-04-08 04:30:00+00:00  2024-04-08T01:30  SWC-AMSR2-X_V2.0_100
# 17 2024-04-09 04:30:00+00:00  2024-04-09T01:30  SWC-AMSR2-X_V2.0_100
# 18 2024-05-03 04:30:00+00:00  2024-05-03T01:30  SWC-AMSR2-X_V2.0_100
# 19 2024-05-06 04:30:00+00:00  2024-05-06T01:30  SWC-AMSR2-X_V2.0_100
#
#     mean_swc  valid_percent                             result_id   status
# 0      0.296            100  f8039419-e19f-4abc-9fb5-dd02dafc5f5c  success
# 1      0.244            100  c70703fb-b171-4735-8074-56db290722ad  success
# 2      0.267            100  f9f672ae-a09f-4642-bf00-4d862b32be3d  success
# 3      0.268            100  16ab2057-c76e-4237-91a1-e2c732bf70de  success
# 4      0.251            100  ab86c7a2-4cd2-4fe4-ab63-ff0419674423  success
# 5        NaN              0  e5ae0314-e617-477b-ba56-f06d540b1b2e  success
# 6      0.218            100  06569674-b885-4f19-a1fb-196a1d9c70d3  success
# 7      0.258            100  1d4c502d-5067-43c9-8436-5e0cd8dfccd3  success
# 8        NaN              0  94ed19b4-412c-4eba-b0b8-323f7636d0f5  success
# 9      0.231            100  9875d3a9-c406-41c3-84dd-cb6a18912471  success
# 10       NaN              0  a5346715-c368-45ad-bef5-e4bde252c723  success
# 11     0.292            100  dc8382cd-004e-49b4-b0bf-de928fa55565  success
# 12       NaN              0  0539705a-7d1d-40e2-97f8-0dde9161802e  success
# 13     0.295            100  b7ce09a8-c936-4949-8a2d-ea9312658814  success
# 14     0.246            100  55bf4251-f50d-41c5-af4a-cbc8704aea3f  success
# 15     0.287            100  63a6c153-3185-4d84-bcb4-29bbaa43a344  success
# 16     0.274            100  1cd581af-6835-4cfb-9851-9a599c7ec381  success
# 17       NaN              0  ba4d9ff1-641d-4dbc-a79a-da054e04e725  success
# 18     0.185            100  230c8122-cb41-463e-925c-1ecc3a7c16ef  success
# 19       NaN              0  8866f5a9-4765-47bb-a6db-2f644c6f39f1  success

# %%
df_valid = df[(df["valid_percent"] >= 0) & (df["mean_swc"].notna())].copy()
df_valid
# Out:
#                 datetime_utc  local_solar_time             source_id  \
# 0  2024-03-21 04:30:00+00:00  2024-03-21T01:30  SWC-AMSR2-X_V2.0_100
# 1  2024-03-22 04:30:00+00:00  2024-03-22T01:30  SWC-AMSR2-X_V2.0_100
# 2  2024-03-23 04:30:00+00:00  2024-03-23T01:30  SWC-AMSR2-X_V2.0_100
# 3  2024-03-25 04:30:00+00:00  2024-03-25T01:30  SWC-AMSR2-X_V2.0_100
# 4  2024-03-27 04:30:00+00:00  2024-03-27T01:30  SWC-AMSR2-X_V2.0_100
# 6  2024-03-29 04:30:00+00:00  2024-03-29T01:30  SWC-AMSR2-X_V2.0_100
# 7  2024-03-30 04:30:00+00:00  2024-03-30T01:30  SWC-AMSR2-X_V2.0_100
# 9  2024-04-01 04:30:00+00:00  2024-04-01T01:30  SWC-AMSR2-X_V2.0_100
# 11 2024-04-03 04:30:00+00:00  2024-04-03T01:30  SWC-AMSR2-X_V2.0_100
# 13 2024-04-05 04:30:00+00:00  2024-04-05T01:30  SWC-AMSR2-X_V2.0_100
# 14 2024-04-06 04:30:00+00:00  2024-04-06T01:30  SWC-AMSR2-X_V2.0_100
# 15 2024-04-07 04:30:00+00:00  2024-04-07T01:30  SWC-AMSR2-X_V2.0_100
# 16 2024-04-08 04:30:00+00:00  2024-04-08T01:30  SWC-AMSR2-X_V2.0_100
# 18 2024-05-03 04:30:00+00:00  2024-05-03T01:30  SWC-AMSR2-X_V2.0_100
#
#     mean_swc  valid_percent                             result_id   status
# 0      0.296            100  f8039419-e19f-4abc-9fb5-dd02dafc5f5c  success
# 1      0.244            100  c70703fb-b171-4735-8074-56db290722ad  success
# 2      0.267            100  f9f672ae-a09f-4642-bf00-4d862b32be3d  success
# 3      0.268            100  16ab2057-c76e-4237-91a1-e2c732bf70de  success
# 4      0.251            100  ab86c7a2-4cd2-4fe4-ab63-ff0419674423  success
# 6      0.218            100  06569674-b885-4f19-a1fb-196a1d9c70d3  success
# 7      0.258            100  1d4c502d-5067-43c9-8436-5e0cd8dfccd3  success
# 9      0.231            100  9875d3a9-c406-41c3-84dd-cb6a18912471  success
# 11     0.292            100  dc8382cd-004e-49b4-b0bf-de928fa55565  success
# 13     0.295            100  b7ce09a8-c936-4949-8a2d-ea9312658814  success
# 14     0.246            100  55bf4251-f50d-41c5-af4a-cbc8704aea3f  success
# 15     0.287            100  63a6c153-3185-4d84-bcb4-29bbaa43a344  success
# 16     0.274            100  1cd581af-6835-4cfb-9851-9a599c7ec381  success
# 18     0.185            100  230c8122-cb41-463e-925c-1ecc3a7c16ef  success

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(df_valid["datetime_utc"], df_valid["mean_swc"])
plt.xlabel("Date (UTC)")
plt.ylabel("SWC mean")
plt.title("Soil Water Content (AOI mean)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
